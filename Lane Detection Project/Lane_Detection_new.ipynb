# %%
import numpy as np
import cv2 as cv 
from matplotlib import pyplot as plt
figsize = (30, 30)

# %%
def region_of_interest(image):
    height = image.shape[0]
    width = image.shape[1]
    mask = np.zeros_like(image) 

    x1_bottom_right= 970
    y1_bottom_right= height-10

    x2_bottom_left=  200
    y2_bottom_left= height-10

    x3_upper_right= 620
    y3_upper_right= 500

    x4_upper_left= 520
    y4_upper_left= 500
    
    pts = np.array([[(x4_upper_left,y4_upper_left), (x2_bottom_left, y2_bottom_left), (x1_bottom_right, y1_bottom_right),(x3_upper_right, y3_upper_right)]] , np.int32)
    cv.fillPoly(mask, pts, 255)  
    masked_image = cv.bitwise_and(image,mask)
    return masked_image

# %%
def apply_color_mask(gray_img,color_img):
  # Converting the image to hsv color space 
  img_hsv = cv.cvtColor(color_img,cv.COLOR_RGB2HSV)

  lower_yellow = np.array([20,100,100], dtype = "uint8")
  upper_yellow = np.array([30,255,255], dtype = "uint8")
  mask_yellow = cv.inRange(img_hsv, lower_yellow,upper_yellow)
 
  lower_white = np.array([0, 0, 231])
  upper_white = np.array([180, 18, 255])
  mask_white  = cv.inRange(gray_img, 170, 255)

  #mask_white = cv.inRange(img_hsv, lower_white, upper_white)
  
  mask_yw = cv.bitwise_or(mask_white, mask_yellow)
  final_img = cv.bitwise_and(gray_img, mask_yw)
  return final_img

# %%
def canny(img):  
    kernel = 7
    blurred = cv.GaussianBlur(img,(kernel, kernel),0)
    canny = cv.Canny(blurred, 150, 200, None, 3) 
    return canny

# %%
def display_lines(image, lines,color=(0,0,255)): 
  lines_img = np.copy(image)
  line_stroke = 2

  if lines is not None: 
    for line in lines:
      x1, y1, x2, y2 = line.reshape(4)
      cv.line(lines_img , (x1,y1) , (x2,y2), color, line_stroke)         

  return lines_img

# %%
def add_text_to_image(text,image, position=(430,100)): 
  font = cv.FONT_HERSHEY_SIMPLEX
  fontScale = 1
  color = (255,255,255) 
  thickness = 2
  image = cv.putText(image, text,position, font, fontScale, color, thickness, cv.LINE_AA) 
  return image

# %%
text = ""
def draw_lane_polygon(image, line1, line2,present,frames):
  lane_image = np.zeros_like(image)
  x1, y1, x2, y2 = line1.reshape(4)
  x3,y3,x4,y4 = line2.reshape(4)
  
  max_base = max(abs(x1 - x2), abs(x3-x4))  
  points = np.array([[(x1,y1), (x2, y2),(x4, y4),(x3,y3)]] , np.int32)
  cv.fillPoly(lane_image, points, color=(150, 0, 0))
  if max_base >= 390 or frames > 0:
    print ('switching lane base:', max_base)
    #update number of frames to print message about lane-change   
    if frames == 0: 
      global text
      text = ""      
      frames = 85      
      if not present[0]:
        text = "Moving to the left lane"
      elif not present[1]:
        text = "Moving to the right lane"   
    add_text_to_image(text,lane_image)
    frames -= 1
  return lane_image, frames

# %%
def make_coordinates(image , line_parameters):
  slope , intercept = line_parameters
  y1 = int(image.shape[0])
  y2 = int(0.72*y1)
  x1 = int((y1-intercept) / slope)
  x2 = int((y2-intercept)/ slope)
  return np.array([x1,y1,x2,y2])

# %%
def average_slope_intercept(image, lines,prev_l,prev_r):
  left_fit    = []
  right_fit   = [] 
  present= [True,True]
  averaged_lines = [] 
  lines_filtered = []
     
  if lines is not None:    
    for line in lines:
      x1, y1, x2, y2 = line.reshape(4)
      slope , intercept = np.polyfit((x2,x1), (y2,y1), 1)   

      if abs(slope) < 0.5:   # 0.4 before
        continue      
      lines_filtered.append(line) #FOR TEST    

      # left lane lines have negative slope
      if slope < 0:
        left_fit.append((slope, intercept))    
      # right lane lines have positive slope 
      if slope > 0:
        right_fit.append((slope,intercept))      

  if len(left_fit) > 0:
    left_fit_average = np.average(left_fit, axis=0)
    slope,intercept = left_fit_average
    left_line =  make_coordinates(image, left_fit_average)
    text_l = f'left line slope={slope} x_val={left_line[0]}'
    #print(text_l)       
  else:
    left_line = prev_l
    present[0] = False 

  if len(right_fit)> 0:
    right_fit_average = np.average(right_fit, axis=0)
    slope,intercept = right_fit_average
    right_line = make_coordinates(image, right_fit_average)
    text_r = f'right line slope={slope} x_val={right_line[0]}' 
    #print(text_r)
  else:
    right_line = prev_r
    present[1] = False  
  
  averaged_lines = [left_line, right_line] 
  
  return present,averaged_lines, lines_filtered

# %% [markdown]
# # Lane Detection On Video

# %%
cap = cv.VideoCapture("test2.mp4")
video_width  = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))  
video_height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))  
video_fps = int(cap.get(cv.CAP_PROP_FPS))
size = (video_width, video_height)
print(f'reading video (fps={video_fps})')
print(f'video dimension ({video_width,video_height})')

from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%H_%M")

# Below VideoWriter object will create video 
# stored in 'output.avi' file.
video = cv.VideoWriter(f'output_{dt_string}.avi', 
                         cv.VideoWriter_fourcc(*'MJPG'),
                         video_fps, size)
test_video = cv.VideoWriter(f'omer_{dt_string}.avi', cv.VideoWriter_fourcc(*'MJPG'),video_fps, size)                        
                         
prev_l = None   #left line from previous frame
prev_r = None   #right line from prrevious frame 
frames = 0   
while(cap.isOpened()):
    ret, frame = cap.read()
    if not ret or cv.waitKey(1) & 0xFF == ord('q'):
        break 
    
    frame = frame.astype(np.uint8)
    frame_out = np.copy(frame)    
    canny_img = canny(frame_out)   
    canny_masked_img = region_of_interest(canny_img)    
    
    #lines = cv.HoughLinesP(canny_masked_img, 2, np.pi/180, 100,np.array([]),minLineLength=10,maxLineGap=10)
    lines = cv.HoughLinesP(canny_masked_img, 2, np.pi/180, 100,np.array([]),minLineLength=10,maxLineGap=70)  
    
    present,averaged_lines, filtered_lines = average_slope_intercept(frame, lines,prev_l,prev_r)
    prev_l,prev_r = averaged_lines[0],averaged_lines[1]
 
    polygon_img , frames =  draw_lane_polygon(frame_out,averaged_lines[0],averaged_lines[1],present,frames)
    combo_img = cv.addWeighted(frame, 0.85, polygon_img, 1, 1) 

     # for testing purposes --------------------------------------------------------------------
    masked_frame = region_of_interest(frame_out)   
    lines_to_display = [] 
    if present[0]:
        lines_to_display.append(averaged_lines[0])
    if present[1]:
        lines_to_display.append(averaged_lines[1])

    test_img = display_lines(masked_frame, lines_to_display,color=(0,0,255))
    test_img = display_lines(masked_frame, filtered_lines,color=(0,0,255))     
    #cv.imshow("lines in roi", test_img)
    # ------------------------------------------------------------------------------------------

    cv.imshow("result", combo_img)
    
    #Writing video
    video.write(combo_img)
    test_video.write(test_img)
 
cap.release()
video.release()
test_video.release()
cv.destroyAllWindows()
# Out:
# reading video (fps=30)
# video dimension ((1280, 720))
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 113
# switching lane base: 146
# switching lane base: 140
# switching lane base: 148
# switching lane base: 154
# switching lane base: 400
# switching lane base: 398
# switching lane base: 396
# switching lane base: 386
# switching lane base: 386
# switching lane base: 382
# switching lane base: 385
# switching lane base: 383
# switching lane base: 374
# switching lane base: 363
# switching lane base: 360
# switching lane base: 360
# switching lane base: 356
# switching lane base: 347
# switching lane base: 344
# switching lane base: 343
# switching lane base: 340
# switching lane base: 337
# switching lane base: 326
# switching lane base: 320
# switching lane base: 320
# switching lane base: 315
# switching lane base: 304
# switching lane base: 306
# switching lane base: 294
# switching lane base: 331
# switching lane base: 396
# switching lane base: 396
# switching lane base: 367
# switching lane base: 376
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 361
# switching lane base: 372
# switching lane base: 381
# switching lane base: 380
# switching lane base: 375
# switching lane base: 375
# switching lane base: 375
# switching lane base: 375
# switching lane base: 375
# switching lane base: 375
# switching lane base: 375
# switching lane base: 366
# switching lane base: 366
# switching lane base: 386
# switching lane base: 391
# switching lane base: 376
# switching lane base: 379
# switching lane base: 354
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 366
# switching lane base: 366
# switching lane base: 377
# switching lane base: 378
# switching lane base: 379
# switching lane base: 375
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 368
# switching lane base: 364
# switching lane base: 350
# switching lane base: 348
# switching lane base: 359
# switching lane base: 343
# switching lane base: 348
# switching lane base: 345
# switching lane base: 345
# switching lane base: 345
# switching lane base: 345
# switching lane base: 345
# switching lane base: 312
# switching lane base: 312
# switching lane base: 312
# switching lane base: 334
# switching lane base: 328
# switching lane base: 320
# switching lane base: 320
# switching lane base: 302
# switching lane base: 302
# switching lane base: 302
# switching lane base: 302
# switching lane base: 302
# switching lane base: 302
# switching lane base: 305
# switching lane base: 310
# switching lane base: 307
# switching lane base: 305
# switching lane base: 314
# switching lane base: 288
# switching lane base: 314
# switching lane base: 314
# switching lane base: 314
# switching lane base: 314
# switching lane base: 314
# switching lane base: 314
# switching lane base: 314
# switching lane base: 391
# switching lane base: 360
# switching lane base: 365
# switching lane base: 352
# switching lane base: 365
# switching lane base: 362
# switching lane base: 362
# switching lane base: 362
# switching lane base: 362
# switching lane base: 362
# switching lane base: 338
# switching lane base: 337
# switching lane base: 336
# switching lane base: 344
# switching lane base: 341
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 324
# switching lane base: 324
# switching lane base: 345
# switching lane base: 347
# switching lane base: 350
# switching lane base: 321
# switching lane base: 335
# switching lane base: 335
# switching lane base: 335
# switching lane base: 343
# switching lane base: 359
# switching lane base: 364
# switching lane base: 349
# switching lane base: 329
# switching lane base: 333
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 350
# switching lane base: 337
# switching lane base: 325
# switching lane base: 324
# switching lane base: 324
# switching lane base: 331
# switching lane base: 331
# switching lane base: 327
# switching lane base: 327
# switching lane base: 327
# switching lane base: 327
# switching lane base: 327
# switching lane base: 336
# switching lane base: 347
# switching lane base: 350
# switching lane base: 328
# switching lane base: 330
# switching lane base: 326
# switching lane base: 327
# switching lane base: 349
# switching lane base: 349
# switching lane base: 349
# switching lane base: 349
# switching lane base: 315
# switching lane base: 325
# switching lane base: 322
# switching lane base: 315
# switching lane base: 330
# switching lane base: 331
# switching lane base: 324
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 323
# switching lane base: 325
# switching lane base: 320
# switching lane base: 324
# switching lane base: 301
# switching lane base: 325
# switching lane base: 325
# switching lane base: 325
# switching lane base: 400
# switching lane base: 364
# switching lane base: 364
# switching lane base: 364
# switching lane base: 364
# switching lane base: 364
# switching lane base: 353
# switching lane base: 353
# switching lane base: 365
# switching lane base: 355
# switching lane base: 338
# switching lane base: 352
# switching lane base: 352
# switching lane base: 352
# switching lane base: 352
# switching lane base: 325
# switching lane base: 342
# switching lane base: 329
# switching lane base: 332
# switching lane base: 329
# switching lane base: 330
# switching lane base: 330
# switching lane base: 363
# switching lane base: 363
# switching lane base: 363
# switching lane base: 363
# switching lane base: 363
# switching lane base: 363
# switching lane base: 331
# switching lane base: 326
# switching lane base: 324
# switching lane base: 312
# switching lane base: 324
# switching lane base: 313
# switching lane base: 349
# switching lane base: 349
# switching lane base: 349
# switching lane base: 349
# switching lane base: 349
# switching lane base: 349
# switching lane base: 311
# switching lane base: 305
# switching lane base: 300
# switching lane base: 296
# switching lane base: 297
# switching lane base: 297
# switching lane base: 299
# switching lane base: 297
# switching lane base: 297
# switching lane base: 297
# switching lane base: 300
# switching lane base: 304
# switching lane base: 300
# switching lane base: 304
# switching lane base: 300
# switching lane base: 303
# switching lane base: 326
# switching lane base: 326
# switching lane base: 326
# switching lane base: 326
# switching lane base: 326
# switching lane base: 326
# switching lane base: 301
# switching lane base: 312
# switching lane base: 309
# switching lane base: 306
# switching lane base: 304
# switching lane base: 310
# switching lane base: 310
# switching lane base: 310
# switching lane base: 310
# switching lane base: 310
# switching lane base: 310
# switching lane base: 308
# switching lane base: 302
# switching lane base: 307
# switching lane base: 301
# switching lane base: 298
# switching lane base: 312
# switching lane base: 312
# switching lane base: 303
# switching lane base: 307
# switching lane base: 306
# switching lane base: 306
# switching lane base: 306
# switching lane base: 401
# switching lane base: 401
# switching lane base: 401
# switching lane base: 347
# switching lane base: 325
# switching lane base: 328
# switching lane base: 320
# switching lane base: 327
# switching lane base: 322
# switching lane base: 324
# switching lane base: 323
# switching lane base: 327
# switching lane base: 327
# switching lane base: 339
# switching lane base: 335
# switching lane base: 339
# switching lane base: 339
# switching lane base: 324
# switching lane base: 330
# switching lane base: 333
# switching lane base: 332
# switching lane base: 333
# switching lane base: 334
# switching lane base: 333
# switching lane base: 334
# switching lane base: 350
# switching lane base: 343
# switching lane base: 342
# switching lane base: 339
# switching lane base: 340
# switching lane base: 340
# switching lane base: 351
# switching lane base: 343
# switching lane base: 345
# switching lane base: 343
# switching lane base: 355
# switching lane base: 355
# switching lane base: 350
# switching lane base: 354
# switching lane base: 351
# switching lane base: 367
# switching lane base: 365
# switching lane base: 356
# switching lane base: 366
# switching lane base: 358
# switching lane base: 355
# switching lane base: 352
# switching lane base: 350
# switching lane base: 356
# switching lane base: 358
# switching lane base: 357
# switching lane base: 356
# switching lane base: 357
# switching lane base: 358
# switching lane base: 360
# switching lane base: 356
# switching lane base: 358
# switching lane base: 360
# switching lane base: 355
# switching lane base: 355
# switching lane base: 357
# switching lane base: 355
# switching lane base: 353
# switching lane base: 350
# switching lane base: 355
# switching lane base: 353
# switching lane base: 350
# switching lane base: 355
# switching lane base: 351
# switching lane base: 358
# switching lane base: 352
# switching lane base: 350
# switching lane base: 347
# switching lane base: 355
# switching lane base: 343
# switching lane base: 350
# switching lane base: 353
# switching lane base: 354
# switching lane base: 351
# switching lane base: 352
# switching lane base: 351
# switching lane base: 349
# switching lane base: 346
# switching lane base: 351
# switching lane base: 345
# switching lane base: 396
# switching lane base: 374
# switching lane base: 394
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 393
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 400
# switching lane base: 396
# switching lane base: 397
# switching lane base: 398
# switching lane base: 400
# switching lane base: 391
# switching lane base: 389
# switching lane base: 378
# switching lane base: 386
# switching lane base: 388
# switching lane base: 386
# switching lane base: 383
# switching lane base: 381
# switching lane base: 376
# switching lane base: 371
# switching lane base: 360
# switching lane base: 371
# switching lane base: 363
# switching lane base: 347
# switching lane base: 358
# switching lane base: 353
# switching lane base: 347
# switching lane base: 346
# switching lane base: 337
# switching lane base: 342
# switching lane base: 330
# switching lane base: 325
# switching lane base: 330
# switching lane base: 321
# switching lane base: 323
# switching lane base: 311
# switching lane base: 317
# switching lane base: 313
# switching lane base: 313
# switching lane base: 313
# switching lane base: 313
# switching lane base: 313
# switching lane base: 403
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 395
# switching lane base: 397
# switching lane base: 397
# switching lane base: 398
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 398
# switching lane base: 398
# switching lane base: 399
# switching lane base: 392
# switching lane base: 393
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 399
# switching lane base: 388
# switching lane base: 396
# switching lane base: 381
# switching lane base: 397
# switching lane base: 397
# switching lane base: 396
# switching lane base: 378
# switching lane base: 378
# switching lane base: 378
# switching lane base: 378
# switching lane base: 378
# switching lane base: 381
# switching lane base: 381
# switching lane base: 365
# switching lane base: 370
# switching lane base: 367
# switching lane base: 382
# switching lane base: 368
# switching lane base: 381
# switching lane base: 379
# switching lane base: 351
# switching lane base: 351
# switching lane base: 351
# switching lane base: 351
# switching lane base: 351
# switching lane base: 351
# switching lane base: 350
# switching lane base: 363
# switching lane base: 364
# switching lane base: 372
# switching lane base: 365
# switching lane base: 381
# switching lane base: 372
# switching lane base: 374
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 357
# switching lane base: 381
# switching lane base: 343
# switching lane base: 391
# switching lane base: 394
# switching lane base: 392
# switching lane base: 397
# switching lane base: 386
# switching lane base: 395
# switching lane base: 395
# switching lane base: 398
# switching lane base: 398
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 400
# switching lane base: 143
# switching lane base: 142
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 149
# switching lane base: 403
# switching lane base: 403
# switching lane base: 403
# switching lane base: 397
# switching lane base: 397
# switching lane base: 397
# switching lane base: 396
# switching lane base: 382
# switching lane base: 380
# switching lane base: 379
# switching lane base: 379
# switching lane base: 373
# switching lane base: 375
# switching lane base: 386
# switching lane base: 395
# switching lane base: 396
# switching lane base: 365
# switching lane base: 366
# switching lane base: 358
# switching lane base: 356
# switching lane base: 362
# switching lane base: 364
# switching lane base: 366
# switching lane base: 366
# switching lane base: 367
# switching lane base: 367
# switching lane base: 367
# switching lane base: 367
# switching lane base: 366
# switching lane base: 364
# switching lane base: 372
# switching lane base: 364
# switching lane base: 359
# switching lane base: 371
# switching lane base: 376
# switching lane base: 368
# switching lane base: 369
# switching lane base: 376
# switching lane base: 376
# switching lane base: 376
# switching lane base: 376
# switching lane base: 376
# switching lane base: 364
# switching lane base: 365
# switching lane base: 391
# switching lane base: 376
# switching lane base: 382
# switching lane base: 384
# switching lane base: 382
# switching lane base: 366
# switching lane base: 369
# switching lane base: 369
# switching lane base: 369
# switching lane base: 369
# switching lane base: 366
# switching lane base: 353
# switching lane base: 373
# switching lane base: 366
# switching lane base: 373
# switching lane base: 377
# switching lane base: 366
# switching lane base: 367
# switching lane base: 369
# switching lane base: 359
# switching lane base: 351
# switching lane base: 351
# switching lane base: 351
# switching lane base: 351
# switching lane base: 375
# switching lane base: 363
# switching lane base: 398
# switching lane base: 383
# switching lane base: 365
# switching lane base: 379
# switching lane base: 368
# switching lane base: 372
# switching lane base: 362
# switching lane base: 388
# switching lane base: 388
# switching lane base: 367
# switching lane base: 363
# switching lane base: 372
# switching lane base: 364
# switching lane base: 359
# switching lane base: 370
# switching lane base: 380
# switching lane base: 366
# switching lane base: 366
# switching lane base: 363
# switching lane base: 376
# switching lane base: 364
# switching lane base: 364
# switching lane base: 364
# switching lane base: 365
# switching lane base: 366
# switching lane base: 357
# switching lane base: 350
# switching lane base: 348
# switching lane base: 348
# switching lane base: 393
# switching lane base: 373
# switching lane base: 381
# switching lane base: 385
# switching lane base: 384
# switching lane base: 377
# switching lane base: 377
# switching lane base: 377
# switching lane base: 382
# switching lane base: 382
# switching lane base: 380
# switching lane base: 366
# switching lane base: 371
# switching lane base: 386
# switching lane base: 377
# switching lane base: 366
# switching lane base: 375
# switching lane base: 377
# switching lane base: 377
# switching lane base: 377
# switching lane base: 377
# switching lane base: 366
# switching lane base: 373
# switching lane base: 373
# switching lane base: 372
# switching lane base: 376
# switching lane base: 382
# switching lane base: 357
# switching lane base: 383
# switching lane base: 382
# switching lane base: 369
# switching lane base: 369
# switching lane base: 369
# switching lane base: 369
# switching lane base: 351
# switching lane base: 397
# switching lane base: 352
# switching lane base: 358
# switching lane base: 365
# switching lane base: 352
# switching lane base: 349
# switching lane base: 359
# switching lane base: 359
# switching lane base: 358
# switching lane base: 358
# switching lane base: 353
# switching lane base: 350
# switching lane base: 360
# switching lane base: 350
# switching lane base: 351
# switching lane base: 360
# switching lane base: 345
# switching lane base: 352
# switching lane base: 351
# switching lane base: 356
# switching lane base: 360
# switching lane base: 360
# switching lane base: 360
# switching lane base: 360
# switching lane base: 352
# switching lane base: 379
# switching lane base: 381
# switching lane base: 344
# switching lane base: 346
# switching lane base: 346
# switching lane base: 363
# switching lane base: 348
# switching lane base: 350
# switching lane base: 352
# switching lane base: 356
# switching lane base: 356
# switching lane base: 356
# switching lane base: 353
# switching lane base: 363
# switching lane base: 354
# switching lane base: 358
# switching lane base: 347
# switching lane base: 344
# switching lane base: 355
# switching lane base: 360
# switching lane base: 363
# switching lane base: 362
# switching lane base: 362
# switching lane base: 362
# switching lane base: 362
# switching lane base: 395
# switching lane base: 358
# switching lane base: 350
# switching lane base: 358
# switching lane base: 356
# switching lane base: 340
# switching lane base: 348
# switching lane base: 356
# switching lane base: 350
# switching lane base: 340
# switching lane base: 340
# switching lane base: 340
# switching lane base: 340
# switching lane base: 340
# switching lane base: 340
# switching lane base: 342
# switching lane base: 348
# switching lane base: 338
# switching lane base: 342
# switching lane base: 339
# switching lane base: 333
# switching lane base: 347
# switching lane base: 347
# switching lane base: 347
# switching lane base: 347
# switching lane base: 336
# switching lane base: 312
# switching lane base: 320
# switching lane base: 316
# switching lane base: 318
# switching lane base: 325
# switching lane base: 314
# switching lane base: 325
# switching lane base: 332
# switching lane base: 325
# switching lane base: 325
# switching lane base: 325
# switching lane base: 325
# switching lane base: 325
# switching lane base: 325
# switching lane base: 337
# switching lane base: 316
# switching lane base: 308
# switching lane base: 313
# switching lane base: 310
# switching lane base: 318
# switching lane base: 324
# switching lane base: 324
# switching lane base: 324
# switching lane base: 324
# switching lane base: 324
# switching lane base: 322
# switching lane base: 311
# switching lane base: 311
# switching lane base: 312
# switching lane base: 309
# switching lane base: 319
# switching lane base: 317
# switching lane base: 310
# switching lane base: 312
# switching lane base: 333
# switching lane base: 333
# switching lane base: 333
# switching lane base: 311
# switching lane base: 310
# switching lane base: 326
# switching lane base: 312
# switching lane base: 317
# switching lane base: 312
# switching lane base: 306
# switching lane base: 316
# switching lane base: 324
# switching lane base: 306
# switching lane base: 306
# switching lane base: 306
# switching lane base: 306
# switching lane base: 306
# switching lane base: 306
# switching lane base: 301
# switching lane base: 317
# switching lane base: 317
# switching lane base: 323
# switching lane base: 319
# switching lane base: 320
# switching lane base: 332
